# %% [markdown]
# <a href="https://colab.research.google.com/github/ngusadeep/python-dsa/blob/main/jovian-dsa-py/1-binary-search_linked-list_complexity/learn0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello samwel")
# Out:
# hello samwel
