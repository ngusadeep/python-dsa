# %% [markdown]
# A deque is a double-ended queue (deque) that supports append and pop elements from both sides
# of the list. Deques are implemented as double-linked lists, which are very efficient for inserting
# and deleting elements in O(1) time complexity.

# %%
from collections import deque

# %%
#create an empty deque
deq_empty = deque()

#another deque
my_deque = deque([34 , 45.6 , 'M' , ['School' , 'Rain']])

# %%
#print its values
print(my_deque)
# Out:
# deque([34, 45.6, 'M', ['School', 'Rain']])

# %% [markdown]
# You can also use some of the following predefined functions:
#
# my_queue.append('age')
# --Insert 'age' at the right end of the list.
#
# my_queue.appendleft('age')
# --Insert 'age' at the left end of the list.
#
# my_queue.pop()
# --Delete the rightmost value.
#
# my_queue.popleft()
# --Delete the leftmost value.
