# %% [markdown]
# An ordered dictionary is a dictionary that preserves the order of the keys that are inserted. If the
# key order is important for any application, then OrderedDict can be used:

# %%
#import module
from collections import OrderedDict

# %%
odr = OrderedDict({'1' : 'This is one' , 'Sept' : 'This is my birthday month' , 2 : 4})
odr['hello'] = 56

#add key value pair
odr['1'] = "Number one!"

# %%
#access data
print(odr)
# Out:
# OrderedDict({'1': 'Number one!', 'Sept': 'This is my birthday month', 2: 4, 'hello': 56})
