# %% [markdown]
# UserDict:
# Python supports a container, UserDict, present in the collections module, that wraps the dictionary
# objects. We can add customized functions to the dictionary. This is very useful for applications
# where we want to add/update/modify the functionalities of the dictionary. Consider the example
# code below where pushing/adding a new data element is not allowed in the dictionary:

# %%
from collections import UserDict

# %%
class Dict(UserDict):
    def push(self , key , value):
        raise RuntimeError('Not Allowed to insert item!')
    
#create dictionary
d = Dict({2.3 : 'Float value' , 34 : 'Integer value' , 34.334 : 'Double value'})

d.push(6778 , 'Integer value')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[9], line 8
#       5 #create dictionary
#       6 d = Dict({2.3 : 'Float value' , 34 : 'Integer value' , 34.334 : 'Double value'})
# ----> 8 d.push(6778 , 'Integer value')
#
# Cell In[9], line 3, in Dict.push(self, key, value)
#       2 def push(self , key , value):
# ----> 3     raise RuntimeError('Not Allowed to insert item!')
#
# RuntimeError: Not Allowed to insert item!

# %% [markdown]
# In the above code, a customized push function in the MyDict class is created to add the customized
# functionality, which does not allow you to insert an element into the dictionary.
